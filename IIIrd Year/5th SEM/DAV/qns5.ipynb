# %%
from sklearn import datasets
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
iris =datasets.load_iris()
print(iris.keys())
df=pd.DataFrame(data=iris.data,columns=iris.feature_names)
df["target"]=iris.target
print(df)
a=df["target"].value_counts()
a
sp=df["target"].unique()
plt.bar(sp,a,color=['red','blue','green'])
plt.xlabel("species")
plt.ylabel("frequency")
plt.show()

df['petal length (cm)'].describe().plot(kind='density')
sns.pairplot(df)
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %%
plt.scatter(df['sepal length (cm)'],df['petal width (cm)'],c=iris.target)
